# %%
# import lib
from sklearn.linear_model import LogisticRegression
# applying the classifier
classifier = LogisticRegression(random_state = 0)
# allpying the model
classifier.fit(xtrain.reshape(xtrain.shape[0],-1), ytrain.reshape(ytrain.shape[0],-1))


# applying the data for the prediction
y_pred = classifier.predict(xtest.reshape(xtest.shape[0],-1))

# cheking the confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest.reshape(ytest.shape[0],-1), y_pred)

print ("Confusion Matrix : \n", cm)


# cheking the accuracy of model
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(ytest.reshape(ytest.shape[0],-1), y_pred))
